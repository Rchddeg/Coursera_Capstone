# %% [markdown]
# ## Peer-graded Assignment: Segmenting and Clustering Neighborhoods in Toronto - Notebook 3
#
# **Author: Rachid de Graaff**

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

# for webscraping import Beautiful Soup 
from bs4 import BeautifulSoup
import xml
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# First, let's scrape the data from the designated page

# %%
url = requests.get('https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M').text
bsoup = BeautifulSoup(url,'lxml')

# %% [markdown]
# Task 1:  The dataframe will consist of three columns: PostalCode, Borough, and Neighborhood

# %%
#Prep the dataframe
table_post = bsoup.find('table')
fields = table_post.find_all('td')

postalcode = []
borough = []
neighbourhood = []

for i in range(0, len(fields), 3):
    postcode.append(fields[i].text.strip())
    borough.append(fields[i+1].text.strip())
    neighbourhood.append(fields[i+2].text.strip())
        
df_pc = pd.DataFrame(data=[postcode, borough, neighbourhood]).transpose()
df_pc.columns = ['Postalcode', 'Borough', 'Neighbourhood']
df_pc.head()
# Out:
#   Postalcode           Borough               Neighbourhood
# 0        M1A      Not assigned
# 1        M2A      Not assigned
# 2        M3A        North York                   Parkwoods
# 3        M4A        North York            Victoria Village
# 4        M5A  Downtown Toronto  Regent Park / Harbourfront

# %% [markdown]
# Task 2: Only process the cells that have an assigned borough. Ignore cells with a borough that is Not assigned.

# %%
#Remove not assigned postalcode
df_pc['Borough'].replace('Not assigned', np.nan, inplace=True)
df_pc.dropna(subset=['Borough'], inplace=True)

df_pc.head()
# Out:
#   Postalcode           Borough                                 Neighbourhood
# 2        M3A        North York                                     Parkwoods
# 3        M4A        North York                              Victoria Village
# 4        M5A  Downtown Toronto                    Regent Park / Harbourfront
# 5        M6A        North York             Lawrence Manor / Lawrence Heights
# 6        M7A  Downtown Toronto  Queen's Park / Ontario Provincial Government

# %% [markdown]
# Task 3: More than one neighborhood can exist in one postal code area. For example, in the table on the Wikipedia page, you will notice that M5A is listed twice and has two neighborhoods: Harbourfront and Regent Park. These two rows will be combined into one row with the neighborhoods separated with a comma.

# %%
df_pcn = df_pc.groupby(['Postalcode', 'Borough'])['Neighbourhood'].apply(', '.join).reset_index()
df_pcn.columns = ['Postalcode', 'Borough', 'Neighbourhood']
df_pcn
# Out:
#     Postalcode      Borough                                      Neighbourhood
# 0          M1B  Scarborough                                    Malvern / Rouge
# 1          M1C  Scarborough           Rouge Hill / Port Union / Highland Creek
# 2          M1E  Scarborough                Guildwood / Morningside / West Hill
# 3          M1G  Scarborough                                             Woburn
# 4          M1H  Scarborough                                          Cedarbrae
# ..         ...          ...                                                ...
# 98         M9N         York                                             Weston
# 99         M9P    Etobicoke                                          Westmount
# 100        M9R    Etobicoke  Kingsview Village / St. Phillips / Martin Grov...
# 101        M9V    Etobicoke  South Steeles / Silverstone / Humbergate / Jam...
# 102        M9W    Etobicoke                                          Northwest
#
# [103 rows x 3 columns]

# %% [markdown]
# If a cell has a borough but a Not assigned neighborhood, then the neighborhood will be the same as the borough.

# %%
#Replace the not assigned neighborhood for Queens park
df_pcn['Neighbourhood'].replace('Not assigned', "Queen's Park", inplace=True)

df_pcn
# Out:
#     Postalcode      Borough                                      Neighbourhood
# 0          M1B  Scarborough                                    Malvern / Rouge
# 1          M1C  Scarborough           Rouge Hill / Port Union / Highland Creek
# 2          M1E  Scarborough                Guildwood / Morningside / West Hill
# 3          M1G  Scarborough                                             Woburn
# 4          M1H  Scarborough                                          Cedarbrae
# ..         ...          ...                                                ...
# 98         M9N         York                                             Weston
# 99         M9P    Etobicoke                                          Westmount
# 100        M9R    Etobicoke  Kingsview Village / St. Phillips / Martin Grov...
# 101        M9V    Etobicoke  South Steeles / Silverstone / Humbergate / Jam...
# 102        M9W    Etobicoke                                          Northwest
#
# [103 rows x 3 columns]

# %%
df_pcn.shape
# Out:
# (103, 3)

# %% [markdown]
# Now that you have built a dataframe of the postal code of each neighborhood along with the borough name and neighborhood name, we need to get the latitude and the longitude coordinates of each neighborhood. See below the dataframe with coordinates.

# %%
df_geo = pd.read_csv('http://cocl.us/Geospatial_data')
df_geo.columns = ['Postalcode', 'Latitude', 'Longitude']

# %%
df_pos = pd.merge(df_pcn, df_geo, on=['Postalcode'], how='inner')

df_tor = df_pos[['Borough', 'Neighbourhood', 'Postalcode', 'Latitude', 'Longitude']].copy()

df_tor.head()
# Out:
#        Borough                             Neighbourhood Postalcode  \
# 0  Scarborough                           Malvern / Rouge        M1B
# 1  Scarborough  Rouge Hill / Port Union / Highland Creek        M1C
# 2  Scarborough       Guildwood / Morningside / West Hill        M1E
# 3  Scarborough                                    Woburn        M1G
# 4  Scarborough                                 Cedarbrae        M1H
#
#     Latitude  Longitude
# 0  43.806686 -79.194353
# 1  43.784535 -79.160497
# 2  43.763573 -79.188711
# 3  43.770992 -79.216917
# 4  43.773136 -79.239476

# %% [markdown]
# Explore and cluster the neighborhoods in Toronto.
#
#
# First, let's set up Foursquare

# %%
CLIENT_ID = 'ID' # your Foursquare ID
CLIENT_SECRET = 'Secret' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: F40VOCBTBO3HZS3KBHEMAD0GOUQ2ABSRJVG0QZ0IYDSWJFN4
# CLIENT_SECRET:4QBM2KE4JWFIZ3LNUITUTKZSGAUC2C2PFL0SVG3JVBQ41YX2

# %%
#Select neighbourhoods in Toronto
df_t4 = df_tor[df_tor['Borough'].str.contains('Toronto')]

to_data = df_t4.reset_index(drop=True)
to_data
# Out:
#              Borough                                      Neighbourhood  \
# 0       East Toronto                                        The Beaches
# 1       East Toronto                      The Danforth West / Riverdale
# 2       East Toronto                    India Bazaar / The Beaches West
# 3       East Toronto                                    Studio District
# 4    Central Toronto                                      Lawrence Park
# 5    Central Toronto                                   Davisville North
# 6    Central Toronto                                 North Toronto West
# 7    Central Toronto                                         Davisville
# 8    Central Toronto                       Moore Park / Summerhill East
# 9    Central Toronto  Summerhill West / Rathnelly / South Hill / For...
# 10  Downtown Toronto                                           Rosedale
# 11  Downtown Toronto                       St. James Town / Cabbagetown
# 12  Downtown Toronto                               Church and Wellesley
# 13  Downtown Toronto                         Regent Park / Harbourfront
# 14  Downtown Toronto                           Garden District, Ryerson
# 15  Downtown Toronto                                     St. James Town
# 16  Downtown Toronto                                        Berczy Park
# 17  Downtown Toronto                                 Central Bay Street
# 18  Downtown Toronto                         Richmond / Adelaide / King
# 19  Downtown Toronto  Harbourfront East / Union Station / Toronto Is...
# 20  Downtown Toronto          Toronto Dominion Centre / Design Exchange
# 21  Downtown Toronto                    Commerce Court / Victoria Hotel
# 22   Central Toronto                                           Roselawn
# 23   Central Toronto                           Forest Hill North & West
# 24   Central Toronto              The Annex / North Midtown / Yorkville
# 25  Downtown Toronto                    University of Toronto / Harbord
# 26  Downtown Toronto        Kensington Market / Chinatown / Grange Park
# 27  Downtown Toronto  CN Tower / King and Spadina / Railway Lands / ...
# 28  Downtown Toronto                                     Stn A PO Boxes
# 29  Downtown Toronto            First Canadian Place / Underground city
# 30  Downtown Toronto                                           Christie
# 31      West Toronto                      Dufferin / Dovercourt Village
# 32      West Toronto                          Little Portugal / Trinity
# 33      West Toronto     Brockton / Parkdale Village / Exhibition Place
# 34      West Toronto                     High Park / The Junction South
# 35      West Toronto                            Parkdale / Roncesvalles
# 36      West Toronto                                Runnymede / Swansea
# 37  Downtown Toronto       Queen's Park / Ontario Provincial Government
# 38      East Toronto              Business reply mail Processing CentrE
#
#    Postalcode   Latitude  Longitude
# 0         M4E  43.676357 -79.293031
# 1         M4K  43.679557 -79.352188
# 2         M4L  43.668999 -79.315572
# 3         M4M  43.659526 -79.340923
# 4         M4N  43.728020 -79.388790
# 5         M4P  43.712751 -79.390197
# 6         M4R  43.715383 -79.405678
# 7         M4S  43.704324 -79.388790
# 8         M4T  43.689574 -79.383160
# 9         M4V  43.686412 -79.400049
# 10        M4W  43.679563 -79.377529
# 11        M4X  43.667967 -79.367675
# 12        M4Y  43.665860 -79.383160
# 13        M5A  43.654260 -79.360636
# 14        M5B  43.657162 -79.378937
# 15        M5C  43.651494 -79.375418
# 16        M5E  43.644771 -79.373306
# 17        M5G  43.657952 -79.387383
# 18        M5H  43.650571 -79.384568
# 19        M5J  43.640816 -79.381752
# 20        M5K  43.647177 -79.381576
# 21        M5L  43.648198 -79.379817
# 22        M5N  43.711695 -79.416936
# 23        M5P  43.696948 -79.411307
# 24        M5R  43.672710 -79.405678
# 25        M5S  43.662696 -79.400049
# 26        M5T  43.653206 -79.400049
# 27        M5V  43.628947 -79.394420
# 28        M5W  43.646435 -79.374846
# 29        M5X  43.648429 -79.382280
# 30        M6G  43.669542 -79.422564
# 31        M6H  43.669005 -79.442259
# 32        M6J  43.647927 -79.419750
# 33        M6K  43.636847 -79.428191
# 34        M6P  43.661608 -79.464763
# 35        M6R  43.648960 -79.456325
# 36        M6S  43.651571 -79.484450
# 37        M7A  43.662301 -79.389494
# 38        M7Y  43.662744 -79.321558

# %%
address = 'Toronto, Canada'
geolocator = Nominatim()
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of the City of Toronto are {}, {}.'.format(latitude, longitude))


#Map of neighbourhoods in Toronto using latitude, longitude values
map_tohood = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighborhood in zip(to_data['Latitude'], to_data['Longitude'], to_data['Borough'], to_data['Neighbourhood']):
    label = '{}, {}'.format(neighborhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=3,
        popup=label,
        color='green',
        fill=True,
        fill_color='#3199cc',
        fill_opacity=0.3,
        parse_html=False).add_to(map_tohood)  
    
map_tohood
# Out:
# /usr/local/lib/python3.6/dist-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning
# The geograpical coordinate of the City of Toronto are 43.6534817, -79.3839347.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Explore neighbourhoods in Toronto, say Riverdale

# %%
to_data.loc[1, 'Neighbourhood'] #exploring first neighbourhood
# Out:
# 'The Danforth West / Riverdale'

# %%
neighbourhood_latitude = to_data.loc[1, 'Latitude'] # neighbourhood latitude value
neighbourhood_longitude = to_data.loc[1, 'Longitude'] # neighbourhood longitude value

neighbourhood_name = to_data.loc[1, 'Neighbourhood'] # neighbourhood name

print('Latitude and longitude values of {} are {}, {}.'.format(neighbourhood_name, 
                                                               neighbourhood_latitude, 
                                                               neighbourhood_longitude))
# Out:
# Latitude and longitude values of The Danforth West / Riverdale are 43.6795571, -79.352188.

# %%
LIMIT = 100
radius = 500

url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    neighbourhood_latitude, 
    neighbourhood_longitude, 
    radius, 
    LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?&client_id=F40VOCBTBO3HZS3KBHEMAD0GOUQ2ABSRJVG0QZ0IYDSWJFN4&client_secret=4QBM2KE4JWFIZ3LNUITUTKZSGAUC2C2PFL0SVG3JVBQ41YX2&v=20180605&ll=43.6795571,-79.352188&radius=500&limit=100'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5e95e064dd0f8500230c4ed6'},
#  'response': {'groups': [{'items': [{'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bce4183ef10952197da8386-0',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'primary': True,
#          'shortName': 'Greek'}],
#        'id': '4bce4183ef10952197da8386',
#        'location': {'address': '407 Danforth Ave.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Chester Ave.',
#         'distance': 223,
#         'formattedAddress': ['407 Danforth Ave. (at Chester Ave.)',
#          'Toronto ON M4K 1P1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67762124481265,
#           'lng': -79.35143390043564}],
#         'lat': 43.67762124481265,
#         'lng': -79.35143390043564,
#         'postalCode': 'M4K 1P1',
#         'state': 'ON'},
#        'name': 'Pantheon',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5102df8df13673cd7084ac39-1',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/beauty_cosmetic_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10c951735',
#          'name': 'Cosmetics Shop',
#          'pluralName': 'Cosmetics Shops',
#          'primary': True,
#          'shortName': 'Cosmetics'}],
#        'id': '5102df8df13673cd7084ac39',
#        'location': {'address': '412 Danforth Ave.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Near Danforth and Chester',
#         'distance': 207,
#         'formattedAddress': ['412 Danforth Ave. (Near Danforth and Chester)',
#          'Toronto ON M4K 1P3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677820068604575,
#           'lng': -79.35126543045044}],
#         'lat': 43.677820068604575,
#         'lng': -79.35126543045044,
#         'postalCode': 'M4K 1P3',
#         'state': 'ON'},
#        'name': 'MenEssentials',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '50073247'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4afdfadff964a520a52c22e3-2',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'primary': True,
#          'shortName': 'Greek'}],
#        'id': '4afdfadff964a520a52c22e3',
#        'location': {'address': '456 Danforth Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Logan Ave.',
#         'distance': 239,
#         'formattedAddress': ['456 Danforth Ave (at Logan Ave.)',
#          'Toronto ON M4K 1P4',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6779622615441,
#           'lng': -79.35019606997218}],
#         'lat': 43.6779622615441,
#         'lng': -79.35019606997218,
#         'postalCode': 'M4K 1P4',
#         'state': 'ON'},
#        'name': 'Mezes',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4e3dbb5e45dd68e3273e03b7-3',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'primary': True,
#          'shortName': 'Italian'}],
#        'id': '4e3dbb5e45dd68e3273e03b7',
#        'location': {'address': '463 Danforth Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Logan Ave',
#         'distance': 261,
#         'formattedAddress': ['463 Danforth Ave (Logan Ave)',
#          'Toronto ON M4K 1P1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677743,
#           'lng': -79.350115}],
#         'lat': 43.677743,
#         'lng': -79.350115,
#         'postalCode': 'M4K 1P1',
#         'state': 'ON'},
#        'name': 'Cafe Fiorentina',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4dc72844d22dafda2fcf75e6-4',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'primary': True,
#          'shortName': 'Ice Cream'}],
#        'id': '4dc72844d22dafda2fcf75e6',
#        'location': {'address': '414 Danforth Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 214,
#         'formattedAddress': ['414 Danforth Ave',
#          'Toronto ON M4K 1P3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677772998450614,
#           'lng': -79.35118737317053}],
#         'lat': 43.677772998450614,
#         'lng': -79.35118737317053,
#         'postalCode': 'M4K 1P3',
#         'state': 'ON'},
#        'name': 'Dolce Gelato',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b677c35f964a520c7512be3-5',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/gym_yogastudio_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d102941735',
#          'name': 'Yoga Studio',
#          'pluralName': 'Yoga Studios',
#          'primary': True,
#          'shortName': 'Yoga Studio'}],
#        'id': '4b677c35f964a520c7512be3',
#        'location': {'address': '372 Danforth Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Chester Ave',
#         'distance': 215,
#         'formattedAddress': ['372 Danforth Ave (at Chester Ave)',
#          'Toronto ON M4K 1N8',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67762174479883,
#           'lng': -79.3521159367257}],
#         'lat': 43.67762174479883,
#         'lng': -79.3521159367257,
#         'postalCode': 'M4K 1N8',
#         'state': 'ON'},
#        'name': 'Moksha Yoga Danforth',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-541ed0a3498e7ff705517bcd-6',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/brewery_',
#           'suffix': '.png'},
#          'id': '50327c8591d4c4b30a586d5d',
#          'name': 'Brewery',
#          'pluralName': 'Breweries',
#          'primary': True,
#          'shortName': 'Brewery'}],
#        'id': '541ed0a3498e7ff705517bcd',
#        'location': {'address': '417 Danforth Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Chester Ave',
#         'distance': 222,
#         'formattedAddress': ['417 Danforth Ave (at Chester Ave)',
#          'Toronto ON M4K 1P1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677662745359996,
#           'lng': -79.3513125762371}],
#         'lat': 43.677662745359996,
#         'lng': -79.3513125762371,
#         'postalCode': 'M4K 1P1',
#         'state': 'ON'},
#        'name': 'Louis Cifer Brew Works',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '95245706'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4aeb268bf964a52006bf21e3-7',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'primary': True,
#          'shortName': 'Greek'}],
#        'id': '4aeb268bf964a52006bf21e3',
#        'location': {'address': '445 Danforth Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Logan Ave',
#         'distance': 232,
#         'formattedAddress': ['445 Danforth Ave (at Logan Ave)',
#          'Toronto ON M4K 1P1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677827494513096,
#           'lng': -79.35056873157725}],
#         'lat': 43.677827494513096,
#         'lng': -79.35056873157725,
#         'postalCode': 'M4K 1P1',
#         'state': 'ON'},
#        'name': 'Messini Authentic Gyros',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-57799e91498e189817c91ead-8',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/icecream_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c9941735',
#          'name': 'Ice Cream Shop',
#          'pluralName': 'Ice Cream Shops',
#          'primary': True,
#          'shortName': 'Ice Cream'}],
#        'id': '57799e91498e189817c91ead',
#        'location': {'address': '372 Danforth Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 225,
#         'formattedAddress': ['372 Danforth Ave',
#          'Toronto ON M4K 1P1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67753,
#           'lng': -79.352295}],
#         'lat': 43.67753,
#         'lng': -79.352295,
#         'postalCode': 'M4K 1P1',
#         'state': 'ON'},
#        'name': 'La Diperie',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ae24088f964a5206b8c21e3-9',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/pub_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d11b941735',
#          'name': 'Pub',
#          'pluralName': 'Pubs',
#          'primary': True,
#          'shortName': 'Pub'}],
#        'id': '4ae24088f964a5206b8c21e3',
#        'location': {'address': '347 Danforth Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Hampton Ave',
#         'distance': 258,
#         'formattedAddress': ['347 Danforth Ave (at Hampton Ave)',
#          'Toronto ON M4K 1N7',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67733505610778,
#           'lng': -79.35312964755529}],
#         'lat': 43.67733505610778,
#         'lng': -79.35312964755529,
#         'postalCode': 'M4K 1N7',
#         'state': 'ON'},
#        'name': 'The Auld Spot Pub',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '569228947'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bb2727135f0c9b66749bb83-10',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'id': '52f2ab2ebcbc57f1066b8b1c',
#          'name': 'Fruit & Vegetable Store',
#          'pluralName': 'Fruit & Vegetable Stores',
#          'primary': True,
#          'shortName': 'Fruit & Vegetable Store'}],
#        'id': '4bb2727135f0c9b66749bb83',
#        'location': {'address': '466 Danforth Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Logan Ave',
#         'distance': 248,
#         'formattedAddress': ['466 Danforth Ave (at Logan Ave)',
#          'Toronto ON M4K 1P4',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677999294687275,
#           'lng': -79.3499690927287}],
#         'lat': 43.677999294687275,
#         'lng': -79.3499690927287,
#         'postalCode': 'M4K 1P4',
#         'state': 'ON'},
#        'name': 'Valley Farm Produce',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4af4e0d0f964a5202ff721e3-11',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'primary': True,
#          'shortName': 'Italian'}],
#        'id': '4af4e0d0f964a5202ff721e3',
#        'location': {'address': '307 Danforth Ave.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Bowden St',
#         'distance': 311,
#         'formattedAddress': ['307 Danforth Ave. (at Bowden St)',
#          'Toronto ON',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677061774959824,
#           'lng': -79.35393428891682}],
#         'lat': 43.677061774959824,
#         'lng': -79.35393428891682,
#         'state': 'ON'},
#        'name': '7 Numbers',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ec857560e6158baffa4fc3c-12',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'primary': True,
#          'shortName': 'Pizza'}],
#        'id': '4ec857560e6158baffa4fc3c',
#        'location': {'address': '550 Danforth Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Carlaw Ave',
#         'distance': 389,
#         'formattedAddress': ['550 Danforth Ave (at Carlaw Ave)',
#          'Toronto ON M4K 1P7',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.678488633358,
#           'lng': -79.34757579277853}],
#         'lat': 43.678488633358,
#         'lng': -79.34757579277853,
#         'postalCode': 'M4K 1P7',
#         'state': 'ON'},
#        'name': 'Pizzeria Libretto',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b26a6a9f964a520ff7e24e3-13',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'primary': True,
#          'shortName': 'Bookstore'}],
#        'id': '4b26a6a9f964a520ff7e24e3',
#        'location': {'address': '548 Danforth Ave.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Carlaw',
#         'distance': 381,
#         'formattedAddress': ['548 Danforth Ave. (Carlaw)',
#          'Toronto ON M4K 1P8',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.678506570428084,
#           'lng': -79.34767758382526}],
#         'lat': 43.678506570428084,
#         'lng': -79.34767758382526,
#         'postalCode': 'M4K 1P8',
#         'state': 'ON'},
#        'name': 'Re: Reading',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5916090a69e77b035ceb1a86-14',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'primary': True,
#          'shortName': 'Restaurant'}],
#        'id': '5916090a69e77b035ceb1a86',
#        'location': {'address': '341 Danforth Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'across from Carrot Common — TTC: Chester',
#         'distance': 269,
#         'formattedAddress': ['341 Danforth Ave (across from Carrot Common — TTC: Chester)',
#          'Toronto ON M4K 1N7',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677267,
#           'lng': -79.353274}],
#         'lat': 43.677267,
#         'lng': -79.353274,
#         'postalCode': 'M4K 1N7',
#         'state': 'ON'},
#        'name': 'Rikkochez',
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '419057819'}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b466804f964a520ed1f26e3-15',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/dessert_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1d0941735',
#          'name': 'Dessert Shop',
#          'pluralName': 'Dessert Shops',
#          'primary': True,
#          'shortName': 'Desserts'}],
#        'id': '4b466804f964a520ed1f26e3',
#        'location': {'address': '400 Danforth Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Chester & Arundel',
#         'distance': 213,
#         'formattedAddress': ['400 Danforth Ave (Chester & Arundel)',
#          'Toronto ON M4K 1P3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67768266377745,
#           'lng': -79.35160842812537}],
#         'lat': 43.67768266377745,
#         'lng': -79.35160842812537,
#         'postalCode': 'M4K 1P3',
#         'state': 'ON'},
#        'name': 'Caffé Demetre',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bd1db4e046076b0f1a57271-16',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/juicebar_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d112941735',
#          'name': 'Juice Bar',
#          'pluralName': 'Juice Bars',
#          'primary': True,
#          'shortName': 'Juice Bar'}],
#        'id': '4bd1db4e046076b0f1a57271',
#        'location': {'address': '348 Danforth Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Hampton Avenue',
#         'distance': 239,
#         'formattedAddress': ['348 Danforth Ave (Hampton Avenue)',
#          'Toronto ON M4K 1N8',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677438,
#           'lng': -79.352683}],
#         'lat': 43.677438,
#         'lng': -79.352683,
#         'postalCode': 'M4K 1N8',
#         'state': 'ON'},
#        'name': 'The Big Carrot Organic Juice Bar',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c508ae15ee81b8d9ee3c5fe-17',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bubble_',
#           'suffix': '.png'},
#          'id': '52e81612bcbc57f1066b7a0c',
#          'name': 'Bubble Tea Shop',
#          'pluralName': 'Bubble Tea Shops',
#          'primary': True,
#          'shortName': 'Bubble Tea'}],
#        'id': '4c508ae15ee81b8d9ee3c5fe',
#        'location': {'address': 'Danforth',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Chester',
#         'distance': 211,
#         'formattedAddress': ['Danforth (Chester)',
#          'Toronto ON M4k 3e3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67776898684133,
#           'lng': -79.35130446081268}],
#         'lat': 43.67776898684133,
#         'lng': -79.35130446081268,
#         'postalCode': 'M4k 3e3',
#         'state': 'ON'},
#        'name': 'Tsaa Tea Shop',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b64ce4af964a52084d12ae3-18',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'primary': True,
#          'shortName': 'Greek'}],
#        'id': '4b64ce4af964a52084d12ae3',
#        'location': {'address': '492 Danforth Avenue',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': '& Logan Av',
#         'distance': 282,
#         'formattedAddress': ['492 Danforth Avenue (& Logan Av)',
#          'Toronto ON M4K 1P6',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.678239784878826,
#           'lng': -79.34918494943804}],
#         'lat': 43.678239784878826,
#         'lng': -79.34918494943804,
#         'postalCode': 'M4K 1P6',
#         'state': 'ON'},
#        'name': "Christina's On The Danforth",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ae29e2af964a520338f21e3-19',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'primary': True,
#          'shortName': 'Greek'}],
#        'id': '4ae29e2af964a520338f21e3',
#        'location': {'address': '484 Danforth Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Logan Ave',
#         'distance': 258,
#         'formattedAddress': ['484 Danforth Ave (Logan Ave)',
#          'Toronto ON',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67830448799868,
#           'lng': -79.34948556208978}],
#         'lat': 43.67830448799868,
#         'lng': -79.34948556208978,
#         'state': 'ON'},
#        'name': 'Alexandros',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ae4bc2ff964a520909d21e3-20',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1ed941735',
#          'name': 'Spa',
#          'pluralName': 'Spas',
#          'primary': True,
#          'shortName': 'Spa'}],
#        'id': '4ae4bc2ff964a520909d21e3',
#        'location': {'address': '179 Danforth Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 479,
#         'formattedAddress': ['179 Danforth Ave', 'Toronto ON', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.676667789021906,
#           'lng': -79.35660190332753}],
#         'lat': 43.676667789021906,
#         'lng': -79.35660190332753,
#         'state': 'ON'},
#        'name': 'Urban Nails',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4be9a0a46295c9b697738508-21',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/hikingtrail_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d159941735',
#          'name': 'Trail',
#          'pluralName': 'Trails',
#          'primary': True,
#          'shortName': 'Trail'}],
#        'id': '4be9a0a46295c9b697738508',
#        'location': {'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 385,
#         'formattedAddress': ['Toronto ON', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67633091997674,
#           'lng': -79.35392333297455}],
#         'lat': 43.67633091997674,
#         'lng': -79.35392333297455,
#         'state': 'ON'},
#        'name': 'Don Valley Trail',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bbe3c929474c9b6d54cd9b6-22',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'primary': True,
#          'shortName': 'Greek'}],
#        'id': '4bbe3c929474c9b6d54cd9b6',
#        'location': {'address': '509 Danforth Ave.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Fenwick Ave.',
#         'distance': 304,
#         'formattedAddress': ['509 Danforth Ave. (at Fenwick Ave.)',
#          'Toronto ON',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67816589533113,
#           'lng': -79.34892679522846}],
#         'lat': 43.67816589533113,
#         'lng': -79.34892679522846,
#         'neighborhood': 'Riverdale',
#         'state': 'ON'},
#        'name': "Athen's Pastries",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bc10b17461576b00f537b32-23',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/diner_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d147941735',
#          'name': 'Diner',
#          'pluralName': 'Diners',
#          'primary': True,
#          'shortName': 'Diner'}],
#        'id': '4bc10b17461576b00f537b32',
#        'location': {'address': '389 Danforth Ave.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Chester',
#         'distance': 221,
#         'formattedAddress': ['389 Danforth Ave. (Chester)',
#          'Toronto ON M4K 1P1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67759437002395,
#           'lng': -79.35176144372598}],
#         'lat': 43.67759437002395,
#         'lng': -79.35176144372598,
#         'postalCode': 'M4K 1P1',
#         'state': 'ON'},
#        'name': 'Detroit Eatery',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4ad4c05ff964a52042f720e3-24',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'primary': True,
#          'shortName': 'Greek'}],
#        'id': '4ad4c05ff964a52042f720e3',
#        'location': {'address': '390 Danforth Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Chester Ave',
#         'distance': 221,
#         'formattedAddress': ['390 Danforth Ave (at Chester Ave)',
#          'Toronto ON M4K 1P3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.677596,
#           'lng': -79.351738}],
#         'lat': 43.677596,
#         'lng': -79.351738,
#         'postalCode': 'M4K 1P3',
#         'state': 'ON'},
#        'name': 'Astoria Shish Kebob House',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-51520f12e4b0506736121eaf-25',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_grocery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d118951735',
#          'name': 'Grocery Store',
#          'pluralName': 'Grocery Stores',
#          'primary': True,
#          'shortName': 'Grocery Store'}],
#        'id': '51520f12e4b0506736121eaf',
#        'location': {'address': '213 Danforth Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 427,
#         'formattedAddress': ['213 Danforth Ave',
#          'Toronto ON M4K 1N2',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67678989740336,
#           'lng': -79.35586511284247}],
#         'lat': 43.67678989740336,
#         'lng': -79.35586511284247,
#         'postalCode': 'M4K 1N2',
#         'state': 'ON'},
#        'name': 'Bulk Barn',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-548b33b0498e29d276209eca-26',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'primary': True,
#          'shortName': 'Furniture / Home'}],
#        'id': '548b33b0498e29d276209eca',
#        'location': {'address': '542 Danforth Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Carlaw Ave',
#         'distance': 372,
#         'formattedAddress': ['542 Danforth Ave (at Carlaw Ave)',
#          'Toronto ON M4K 1P8',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.678477,
#           'lng': -79.347811}],
#         'lat': 43.678477,
#         'lng': -79.347811,
#         'neighborhood': 'Greektown',
#         'postalCode': 'M4K 1P8',
#         'state': 'ON'},
#        'name': 'IQ Living',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d1263edd0fda0934094ab57-27',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/cafe_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16d941735',
#          'name': 'Café',
#          'pluralName': 'Cafés',
#          'primary': True,
#          'shortName': 'Café'}],
#        'id': '4d1263edd0fda0934094ab57',
#        'location': {'address': 'Danforth Ave.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Logan Ave.',
#         'distance': 270,
#         'formattedAddress': ['Danforth Ave. (Logan Ave.)',
#          'Toronto ON',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67811808012494,
#           'lng': -79.34948504099059}],
#         'lat': 43.67811808012494,
#         'lng': -79.34948504099059,
#         'state': 'ON'},
#        'name': 'Leonidas Chocolates Cafe',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-55fc0110498ecbc14aa76933-28',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '55fc0110498ecbc14aa76933',
#        'location': {'address': '792 Carlaw Ave.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Danforth',
#         'distance': 394,
#         'formattedAddress': ['792 Carlaw Ave. (Danforth)',
#          'Toronto ON',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.678629530863844,
#           'lng': -79.34746013725268}],
#         'lat': 43.678629530863844,
#         'lng': -79.34746013725268,
#         'state': 'ON'},
#        'name': 'Marvel Coffee Co.',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4aec8fe3f964a520bcc821e3-29',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bakery_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d16a941735',
#          'name': 'Bakery',
#          'pluralName': 'Bakeries',
#          'primary': True,
#          'shortName': 'Bakery'}],
#        'id': '4aec8fe3f964a520bcc821e3',
#        'location': {'address': '173 Danforth Ave.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Broadview',
#         'distance': 495,
#         'formattedAddress': ['173 Danforth Ave. (Broadview)',
#          'Toronto ON M4K 1N2',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67664308520287,
#           'lng': -79.35684634585105}],
#         'lat': 43.67664308520287,
#         'lng': -79.35684634585105,
#         'postalCode': 'M4K 1N2',
#         'state': 'ON'},
#        'name': 'Dough Bakeshop',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4afc9333f964a5200c2422e3-30',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/greek_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10e941735',
#          'name': 'Greek Restaurant',
#          'pluralName': 'Greek Restaurants',
#          'primary': True,
#          'shortName': 'Greek'}],
#        'id': '4afc9333f964a5200c2422e3',
#        'location': {'address': '420 Danforth Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 193,
#         'formattedAddress': ['420 Danforth Ave',
#          'Toronto ON M4K 1P3',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6779727,
#           'lng': -79.3512077}],
#         'lat': 43.6779727,
#         'lng': -79.3512077,
#         'postalCode': 'M4K 1P3',
#         'state': 'ON'},
#        'name': 'Kalyvia',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5269ba3c498ea63de3eb987b-31',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/caribbean_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d144941735',
#          'name': 'Caribbean Restaurant',
#          'pluralName': 'Caribbean Restaurants',
#          'primary': True,
#          'shortName': 'Caribbean'}],
#        'id': '5269ba3c498ea63de3eb987b',
#        'location': {'address': '596 Danforth Avenue',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Pape And Danforth',
#         'distance': 462,
#         'formattedAddress': ['596 Danforth Avenue (Pape And Danforth)',
#          'Toronto ON M4K 1R1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67865547474292,
#           'lng': -79.34658157954753}],
#         'lat': 43.67865547474292,
#         'lng': -79.34658157954753,
#         'postalCode': 'M4K 1R1',
#         'state': 'ON'},
#        'name': "Simone's Caribbean Restaurant",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b76b3d2f964a52064592ee3-32',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'primary': True,
#          'shortName': 'Restaurant'}],
#        'id': '4b76b3d2f964a52064592ee3',
#        'location': {'address': '348 Danforth Ave.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Jackman Ave.',
#         'distance': 241,
#         'formattedAddress': ['348 Danforth Ave. (Jackman Ave.)',
#          'Toronto ON M4K 2Z1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.6774845518262,
#           'lng': -79.35307562861175}],
#         'lat': 43.6774845518262,
#         'lng': -79.35307562861175,
#         'postalCode': 'M4K 2Z1',
#         'state': 'ON'},
#        'name': 'Carrot Commons',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b8d7b70f964a52063fe32e3-33',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '4b8d7b70f964a52063fe32e3',
#        'location': {'address': '521 Danforth Ave.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Fenwick Avenue',
#         'distance': 341,
#         'formattedAddress': ['521 Danforth Ave. (Fenwick Avenue)',
#          'Toronto ON M4K 1P5',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67812618087551,
#           'lng': -79.34843379217203}],
#         'lat': 43.67812618087551,
#         'lng': -79.34843379217203,
#         'postalCode': 'M4K 1P5',
#         'state': 'ON'},
#        'name': 'Cafe Frappe',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4c1d5337eac020a1cb1048c2-34',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d10f941735',
#          'name': 'Indian Restaurant',
#          'pluralName': 'Indian Restaurants',
#          'primary': True,
#          'shortName': 'Indian'}],
#        'id': '4c1d5337eac020a1cb1048c2',
#        'location': {'address': '351 Danforth Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Jackman Ave',
#         'distance': 260,
#         'formattedAddress': ['351 Danforth Ave (at Jackman Ave)',
#          'Toronto ON M4K 1N7',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67730788939673,
#           'lng': -79.35306551709385}],
#         'lat': 43.67730788939673,
#         'lng': -79.35306551709385,
#         'postalCode': 'M4K 1N7',
#         'state': 'ON'},
#        'name': 'Sher-E-Punjab',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4d28fa67ebacb1f7f37ff64f-35',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d14e941735',
#          'name': 'American Restaurant',
#          'pluralName': 'American Restaurants',
#          'primary': True,
#          'shortName': 'American'}],
#        'id': '4d28fa67ebacb1f7f37ff64f',
#        'location': {'address': '193 Danforth Ave.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 459,
#         'formattedAddress': ['193 Danforth Ave.',
#          'Toronto ON M4K 1N2',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67669287762859,
#           'lng': -79.35629876225282}],
#         'lat': 43.67669287762859,
#         'lng': -79.35629876225282,
#         'postalCode': 'M4K 1N2',
#         'state': 'ON'},
#        'name': 'Factory Girl',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-516c9d2de4b0cde235a2cb1a-36',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/frozenyogurt_',
#           'suffix': '.png'},
#          'id': '512e7cae91d4cbb4e5efe0af',
#          'name': 'Frozen Yogurt Shop',
#          'pluralName': 'Frozen Yogurt Shops',
#          'primary': True,
#          'shortName': 'Yogurt'}],
#        'id': '516c9d2de4b0cde235a2cb1a',
#        'location': {'address': 'Danforth Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'Pape',
#         'distance': 356,
#         'formattedAddress': ['Danforth Ave (Pape)', 'Toronto ON', 'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67830909198205,
#           'lng': -79.34810528402672}],
#         'lat': 43.67830909198205,
#         'lng': -79.34810528402672,
#         'state': 'ON'},
#        'name': "Menchie's",
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4af6e7a0f964a520060422e3-37',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/italian_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d110941735',
#          'name': 'Italian Restaurant',
#          'pluralName': 'Italian Restaurants',
#          'primary': True,
#          'shortName': 'Italian'}],
#        'id': '4af6e7a0f964a520060422e3',
#        'location': {'address': '576 Danforth Ave.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'distance': 438,
#         'formattedAddress': ['576 Danforth Ave.',
#          'Toronto ON M4K 1R1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67860392856738,
#           'lng': -79.34690364849348}],
#         'lat': 43.67860392856738,
#         'lng': -79.34690364849348,
#         'postalCode': 'M4K 1R1',
#         'state': 'ON'},
#        'name': 'IL FORNELLO on Danforth',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4af374dbf964a520d8ed21e3-38',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/default_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d121941735',
#          'name': 'Lounge',
#          'pluralName': 'Lounges',
#          'primary': True,
#          'shortName': 'Lounge'}],
#        'id': '4af374dbf964a520d8ed21e3',
#        'location': {'address': '511 Danforth Ave.',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Ferrier Ave.',
#         'distance': 332,
#         'formattedAddress': ['511 Danforth Ave. (at Ferrier Ave.)',
#          'Toronto ON M4K 1P5',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67793098663968,
#           'lng': -79.34872380466781}],
#         'lat': 43.67793098663968,
#         'lng': -79.34872380466781,
#         'postalCode': 'M4K 1P5',
#         'state': 'ON'},
#        'name': 'Bar Oak',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4b7846f5f964a52079c12ee3-39',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bookstore_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d114951735',
#          'name': 'Bookstore',
#          'pluralName': 'Bookstores',
#          'primary': True,
#          'shortName': 'Bookstore'}],
#        'id': '4b7846f5f964a52079c12ee3',
#        'location': {'address': '348 Danforth Avenue',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'near Chester',
#         'distance': 242,
#         'formattedAddress': ['348 Danforth Avenue (near Chester)',
#          'Toronto ON',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67741319707514,
#           'lng': -79.3527341009978}],
#         'lat': 43.67741319707514,
#         'lng': -79.3527341009978,
#         'state': 'ON'},
#        'name': 'Book City',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4bc0ea4df8219c74807ab210-40',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/food_liquor_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d186941735',
#          'name': 'Liquor Store',
#          'pluralName': 'Liquor Stores',
#          'primary': True,
#          'shortName': 'Liquor Store'}],
#        'id': '4bc0ea4df8219c74807ab210',
#        'location': {'address': '200 Danforth Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'btwn Pretoria & Playter',
#         'distance': 435,
#         'formattedAddress': ['200 Danforth Ave (btwn Pretoria & Playter)',
#          'Toronto ON M4K 1N5',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.676815838008714,
#           'lng': -79.35604671347544}],
#         'lat': 43.676815838008714,
#         'lng': -79.35604671347544,
#         'postalCode': 'M4K 1N5',
#         'state': 'ON'},
#        'name': 'LCBO',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-5246dbd611d23c6130e650a0-41',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/furniture_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1f8941735',
#          'name': 'Furniture / Home Store',
#          'pluralName': 'Furniture / Home Stores',
#          'primary': True,
#          'shortName': 'Furniture / Home'}],
#        'id': '5246dbd611d23c6130e650a0',
#        'location': {'address': '583 Danforth Ave',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Gough Ave',
#         'distance': 475,
#         'formattedAddress': ['583 Danforth Ave (at Gough Ave)',
#          'Toronto ON M4K 1P9',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.67861256318158,
#           'lng': -79.34642163596001}],
#         'lat': 43.67861256318158,
#         'lng': -79.34642163596001,
#         'postalCode': 'M4K 1P9',
#         'state': 'ON'},
#        'name': 'Kitchen Stuff Plus',
#        'photos': {'count': 0, 'groups': []}}},
#      {'reasons': {'count': 0,
#        'items': [{'reasonName': 'globalInteractionReason',
#          'summary': 'This spot is popular',
#          'type': 'general'}]},
#       'referralId': 'e-0-4adcba1cf964a520272f21e3-42',
#       'venue': {'categories': [{'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/coffeeshop_',
#           'suffix': '.png'},
#          'id': '4bf58dd8d48988d1e0931735',
#          'name': 'Coffee Shop',
#          'pluralName': 'Coffee Shops',
#          'primary': True,
#          'shortName': 'Coffee Shop'}],
#        'id': '4adcba1cf964a520272f21e3',
#        'location': {'address': '604 Danforth Avenue',
#         'cc': 'CA',
#         'city': 'Toronto',
#         'country': 'Canada',
#         'crossStreet': 'at Gough Ave.',
#         'distance': 475,
#         'formattedAddress': ['604 Danforth Avenue (at Gough Ave.)',
#          'Toronto ON M4K 1R1',
#          'Canada'],
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 43.678879,
#           'lng': -79.346357}],
#         'lat': 43.678879,
#         'lng': -79.346357,
#         'postalCode': 'M4K 1R1',
#         'state': 'ON'},
#        'name': 'Starbucks',
#        'photos': {'count': 0, 'groups': []}}}],
#     'name': 'recommended',
#     'type': 'Recommended Places'}],
#   'headerFullLocation': 'Greektown, Toronto',
#   'headerLocation': 'Greektown',
#   'headerLocationGranularity': 'neighborhood',
#   'suggestedBounds': {'ne': {'lat': 43.6840571045, 'lng': -79.34597738331301},
#    'sw': {'lat': 43.675057095499994, 'lng': -79.35839861668698}},
#   'suggestedFilters': {'filters': [{'key': 'openNow', 'name': 'Open now'}],
#    'header': 'Tap to show:'},
#   'totalResults': 43}}
